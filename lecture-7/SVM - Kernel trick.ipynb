# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df=pd.read_csv('dose.csv')
dosage = df['dosage']
y_data = len(dosage)*[10]
# plt.rcParams['figure.figsize'] = [10, 10]
plt.scatter(x=dosage, y=y_data, c=df['e2'], s=5)

# %%
y_data = np.power(dosage,5+4)
# 
x=plt.scatter(x=dosage, y=y_data, c=df['e2'], s=15)
x
